# %%
from src.trainers.memeclf import MemeClfTrainer

# %%
MemeClf = MemeClfTrainer()
# Out:
# Do you want fresh?

# %%
MemeClf.train(trigger1=0.80,trigger2=0.9,finish=0.99,num_workers=64, num_epochs=1000)
# Out:
# num wrong names - 68
#        name  iteration num_correct val_num_correct  current_val_acc  \
# 0  meme_clf        305     467/493         465/493         0.943205
#
#    max_val_acc  patience  max_patience  current_acc   max_acc  min_loss  \
# 0     0.947262        16            58     0.947262  0.947262  5.266965
#
#    num_left
# 0       983
# timestamp: 11:39:51
# model_runtime: 3 minutes 10 seconds
# uptime: 1 hour 47 minutes 18 seconds
# total_time: 14 hours 50 minutes 38 seconds
# eta: 1 day 23 hours 50 minutes 28 seconds
# ['afraid to ask andy', 'ah shit here we go again', 'allow us to introduce ourselves', 'ancient aliens', 'and just like that', 'bad luck brian', 'bernie sanders reaction nuked', 'boy and girl texting', 'bro not cool', 'captain picard facepalm', 'chuckles im in danger', 'clown applying makeup', 'cmon do something', 'confucius says', 'crying baby yoda', 'crying peter parker', 'dabbing dude', 'doge', 'donald trump', 'elmo cocaine', 'expanding brain', 'fallout hold up', 'how tough are you', 'i am inevitable', 'i wish all the x a very pleasant evening', 'ill have you know spongebob', 'internet explorer', 'jack sparrow being chased', 'jim halpert explains', 'jordan peele sweating', 'laughing leo', 'lisa simpson coffee that x shit', 'look at me', 'lumbergh', 'madea with gun', 'mike wazowski trying to explain', 'minor mistake marvin', 'mugatu so hot right now', 'one does not simply', 'panik kalm panik', 'persian cat room guardian', 'pink guy vs bane', 'rick and morty-extra steps', 'running away balloon', 'scumbag steve', 'shut up and take my money fry', 'so anyway i started blasting', 'sparta leonidas', 'spongebob rainbow', 'squidward', 'srgrafo dude wtf', 'star wars yoda', 'stonks helth', 'surprised koala', 'team rocket', 'the most interesting man in the world', 'the silent protector', 'third world skeptical kid', 'this little manuever is gonna cost us 51 years', 'too damn high', 'two buttons', 'wait thats illegal', 'we dont do that here', 'what if you wanted to go to heaven', 'willy wonka blank', 'x all the y', 'yall got any more of', 'yugioh card draw']
# C:\ProgramData\Anaconda3\envs\mh\lib\site-packages\torch\utils\data\dataloader.py:474: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32 (`cpuset` is not taken into account), which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
MemeClf.print_graphs()

# %%
# %matplotlib inline
MemeClf.test_model(only_wrong=True)

# %%
memeclf_to_aws(True)
