# %%
from src.trainers.memeclf import MemeClfTrainer

# %%
MemeClf = MemeClfTrainer()
# Out:
# Do you want fresh? y

# %%
# MemeClf.lr_fider(start_lr=0.0000001, end_lr=1, num_iter=10000)

# %%
MemeClf.train()
# Out:
#        name  iteration      loss  patience  max_patience  num_left  min_loss
# 0  meme_clf          4  5.977426         0             1       996  5.977426
#   val_correct  val_acc  max_val_acc  correct    acc  max_acc trans_correct  \
# 0     27/6352    0.004        0.004  21/6352  0.003    0.004       28/6352
#
#    trans_acc  max_trans_acc
# 0      0.004          0.004
# wrong_name_round: 0
# hard_resets: 0
# timestamp: 18:06:34
# model_runtime: 6 minutes 57 seconds
# uptime: 25 minutes 41 seconds
# total_time: 25 minutes 44 seconds
# eta: 4 days 10 hours 47 minutes 36 seconds

# %%
MemeClf.print_graphs()

# %%
# %matplotlib inline
MemeClf.test_model(only_wrong=True)

# %%
memeclf_to_aws(True)

# %%
str("hgterg_htrgher_htrhtgre")
