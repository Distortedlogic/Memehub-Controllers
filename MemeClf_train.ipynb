# %%
from src.trainers.memeclf import MemeClfTrainer

# %%
MemeClf = MemeClfTrainer()
# Out:
# Do you want fresh? y

# %%
MemeClf.train()
# Out:
# num wrong names - 42
#        name  iteration num_correct val_num_correct  current_val_acc  \
# 0  meme_clf        531     402/412         398/412         0.966019
#
#    max_val_acc  patience  max_patience  current_acc   max_acc  min_loss  \
# 0     0.975728        11            43     0.975728  0.975728  5.159771
#
#    num_left
# 0       882
# hard_resets: 0
# timestamp: 16:15:42
# model_runtime: 48 seconds
# uptime: 16 hours 54 minutes 26 seconds
# total_time: 16 hours 58 minutes 50 seconds
# eta: 1 day 4 hours 12 minutes 17 seconds
# ['advice dog', 'afraid to ask andy', 'ancient aliens', 'anime girl hiding from terminator', 'back in my day', 'captain picard facepalm', 'crying peter parker', 'disappointed black guy', 'dr evil', 'dw sign wont stop me because i cant read', 'eddie murphy thinking', 'elmo cocaine', 'finally! a worthy opponent!', 'gadsden flag', 'god', 'good fellas hilarious', 'grandma finds the internet', 'gru gun', 'i am speed', 'i should buy a boat cat', 'inhaling seagull', 'is for me', 'jack sparrow you have heard of me', 'jim halpert explains', 'knights of the round table', 'leonardo dicaprio cheers', 'madea with gun', 'mario bros views', 'marvel civil war', 'minor mistake marvin', 'mocking spongebob', 'moe throws barney', 'omg karen', 'put it somewhere else patrick', 'shut up and take my money fry', 'stonks', 'the silent protector', 'triggered feminist', 'undertaker', 'well yes but actually no', 'whatcha got there', 'you wouldnt get it']
# C:\ProgramData\Anaconda3\envs\mh\lib\site-packages\torch\utils\data\dataloader.py:474: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32 (`cpuset` is not taken into account), which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
MemeClf.print_graphs()

# %%
# %matplotlib inline
MemeClf.test_model(only_wrong=True)

# %%
memeclf_to_aws(True)
