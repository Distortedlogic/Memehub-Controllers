# %%
from src.trainers.memeclf import MemeClfTrainer

# %%
MemeClf = MemeClfTrainer()
# Out:
# Do you want fresh? y

# %%
MemeClf.train(trigger1=0.80,trigger2=0.9,finish=0.99,num_workers=16, num_epochs=1000)
# Out:
# num wrong names - 60
#        name  iteration num_correct val_num_correct  current_val_acc  \
# 0  meme_clf        295     470/493         471/493         0.955375
#
#    max_val_acc  patience  max_patience  current_acc   max_acc  min_loss  \
# 0     0.955375        11            34     0.953347  0.957404  5.402897
#
#    num_left
# 0       941
# hard_resets: 0
# timestamp: 09:45:03
# model_runtime: 49 seconds
# uptime: 11 hours 31 minutes 50 seconds
# total_time: 11 hours 34 minutes 12 seconds
# eta: 1 day 12 hours 54 minutes 22 seconds
# ['1990s first world problems', 'advice dog', 'advice yoda', 'allow us to introduce ourselves', 'always has been', 'arthur fist', 'baby yoda', 'bazooka squirrel', 'black guy disappearing', 'boardroom meeting suggestion', 'boy and girl texting', 'buddy christ', 'buff doge vs crying cheems', 'car salesman slaps roof of car', 'charlie day', 'clown applying makeup', 'communist bugs bunny', 'doge', 'dr evil', 'dwight schrute', 'eddie murphy thinking', 'epic handshake', 'farquaad pointing', 'for christmas i want a dragon', 'gangnam style', 'gordon ramsay some good food', 'grandma finds the internet', 'gru gun', 'grumpy cat', 'i am speed', 'i bet hes thinking about other women', 'ill have you know spongebob', 'ill just wait here', 'imagination spongebob', 'laughing leo', 'laughing wolf', 'leonardo dicaprio cheers', 'leonardo dicaprio pointing', 'metal jesus', 'moe throws barney', 'mr t pity the fool', 'nuclear explosion', 'oh no! anyway', 'pink guy vs bane', 'ppap', 'ptsd chihuahua', 'running away balloon', 'samuel l jackson', 'shut up and take my money fry', 'soldier protecting sleeping child', 'squidward chair', 'the scroll of truth', 'they dont know', 'this little manuever is gonna cost us 51 years', 'thor is he though', 'two buttons', 'undertaker', 'whatcha got there', 'yall got any more of', 'you wouldnt get it']

# %%
MemeClf.print_graphs()

# %%
# %matplotlib inline
MemeClf.test_model(only_wrong=True)

# %%
memeclf_to_aws(True)
