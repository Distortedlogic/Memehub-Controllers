# %%
from src.trainers.memeclf import MemeClfTrainer

# %%
MemeClf = MemeClfTrainer()
# Out:
# Do you want fresh? y

# %%
# MemeClf.lr_fider(start_lr=0.0000001, end_lr=1, num_iter=10000)

# %%
MemeClf.train()
# Out:
#        name  iteration      loss  patience  max_patience  num_left  min_loss
# 0  meme_clf        240  0.584701        12            12       760  0.584701
#   val_correct  val_acc  max_val_acc    correct    acc  max_acc trans_correct  \
# 0   6299/6464    0.974        0.976  6311/6464  0.976    0.977     6248/6464
#
#    trans_acc  max_trans_acc
# 0      0.967           0.97
# wrong_name_round: 0
# hard_resets: 0
# timestamp: 15:31:25
# model_runtime: 5 minutes 27 seconds
# uptime: 19 hours 37 minutes 18 seconds
# total_time: 19 hours 39 minutes 7 seconds
# eta: 2 days 14 hours 13 minutes 52 seconds
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\envs\mh\lib\site-packages\IPython\core\interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-4-c934111b0017>", line 1, in <module>
# ...

# %%
MemeClf.print_graphs()

# %%
# %matplotlib inline
MemeClf.test_model(only_wrong=True,is_training=True,use_transforms=True,is_validation=False)

# %%
memeclf_to_aws(True)

# %%
str("hgterg_htrgher_htrhtgre")
