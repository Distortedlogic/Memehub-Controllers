# %%
from src.trainers.not_a_meme import NotAMemeClfTrainer

# %%
NotAMemeClf=NotAMemeClfTrainer()
# Out:
# Do you want fresh? y

# %%
NotAMemeClf.train(num_workers=64, num_epochs=1000)
# Out:
# C:\ProgramData\Anaconda3\envs\mh\lib\site-packages\torch\utils\data\dataloader.py:474: UserWarning: This DataLoader will create 64 worker processes in total. Our suggested max number of worker in current system is 32 (`cpuset` is not taken into account), which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-3e9f204b61ef> in <module>
# ----> 1 NotAMemeClf.train(num_workers=64, num_epochs=1000)
#
# C:\github\Memehub\Memehub-Python\src\trainers\not_a_meme.py in train(self, num_workers, num_epochs)
#     189         self.begin = int(time.time())
#     190         self.now = time.time()
# --> 191         self.train_full()
#     192
#     193     def train_full(self):
#
# C:\github\Memehub\Memehub-Python\src\trainers\not_a_meme.py in train_full(self)
#     193     def train_full(self):
#     194         for self.epoch in range(1, self.num_epochs):
# --> 195             self.train_epoch(
#     196                 NotAMemeClfSet(
#     197                     self.static["max_name_idx"],
#
# C:\github\Memehub\Memehub-Python\src\trainers\not_a_meme.py in train_epoch(self, dataset, batch_size, num_workers)
#     178         ):
#     179             self.losses.append(
# --> 180                 self.model.train_step(
#     181                     inputs.to(device), labels.to(device, dtype=torch.float)
#     182                 )
#
# C:\github\Memehub\Memehub-Python\src\trainers\not_a_meme.py in train_step(self, batch, labels)
#      73         self.features_opt.zero_grad()
#      74         self.dense_opt.zero_grad()
# ---> 75         pred = self.forward(batch)
#      76         loss = self.loss_func(pred, labels)
#      77         loss.backward(torch.ones_like(loss))
#
# C:\github\Memehub\Memehub-Python\src\trainers\not_a_meme.py in forward(self, images)
#      81
#      82     def forward(self, images: torch.Tensor) -> torch.Tensor:
# ---> 83         features = self.features(images)
#      84         dense = self.dense(features)
#      85         squeezed = torch.squeeze(dense, dim=1)
#
# C:\ProgramData\Anaconda3\envs\mh\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# C:\ProgramData\Anaconda3\envs\mh\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     117     def forward(self, input):
#     118         for module in self:
# --> 119             input = module(input)
#     120         return input
#     121
#
# C:\ProgramData\Anaconda3\envs\mh\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# C:\ProgramData\Anaconda3\envs\mh\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     117     def forward(self, input):
#     118         for module in self:
# --> 119             input = module(input)
#     120         return input
#     121
#
# C:\ProgramData\Anaconda3\envs\mh\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# C:\ProgramData\Anaconda3\envs\mh\lib\site-packages\torch\nn\modules\pooling.py in forward(self, input)
#     160
#     161     def forward(self, input: Tensor) -> Tensor:
# --> 162         return F.max_pool2d(input, self.kernel_size, self.stride,
#     163                             self.padding, self.dilation, self.ceil_mode,
#     164                             self.return_indices)
#
# C:\ProgramData\Anaconda3\envs\mh\lib\site-packages\torch\_jit_internal.py in fn(*args, **kwargs)
#     363             return if_true(*args, **kwargs)
#     364         else:
# --> 365             return if_false(*args, **kwargs)
#     366
#     367     if if_true.__doc__ is None and if_false.__doc__ is not None:
#
# C:\ProgramData\Anaconda3\envs\mh\lib\site-packages\torch\nn\functional.py in _max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode, return_indices)
#     657     if stride is None:
#     658         stride = torch.jit.annotate(List[int], [])
# --> 659     return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
#     660
#     661
#
# RuntimeError: CUDA out of memory. Tried to allocate 98.00 MiB (GPU 0; 11.00 GiB total capacity; 4.27 GiB already allocated; 0 bytes free; 4.28 GiB reserved in total by PyTorch)
