# %%
from src.stonks.market import StonkMarket

# %%
stonks=StonkMarket()

# %%
stonks.print_market()
# Out:
#                                                   name  num_posts  \
# 0                            grim reaper knocking door        161
# 1                                          drake noyes         59
# 2                                           fancy pooh         31
# 3                                     panik kalm panik         27
# 4                                       change my mind         26
# 5                               disappointed black guy         25
# 6                           buff doge vs crying cheems         20
# 7                           lisa simpsons presentation         18
# 8                                          two buttons         17
# 9                                      expanding brain         15
# 10                                       vince mcmahon         14
# 11                 what gives people feelings of power         14
# 12                                      they dont know         14
# ...

# %%
with APP.app_context():
    audit_is_template()
