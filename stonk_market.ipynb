# %%
from src.reddit.stonks import print_market

# %%
print_market()
# Out:
#                                                name  num_posts  total_upvotes  \
# 0                                        not_a_meme        179         106465
# 1                         thanos perfectly balanced         13            239
# 2                              maybe i am a monster          9          60422
# 3                                  panik kalm panik          8            184
# 4                                       two buttons          8            515
# 5               what gives people feelings of power          7            136
# 6                                 visible confusion          7          14484
# 7                                      where banana          6            403
# 8                                        undertaker          6          24080
# 9                              running away balloon          5            161
# 10                              why is the fbi here          5            302
# ...

# %%
with APP.app_context():
    audit_is_template()
