# %%
from src.stonks.market import StonkMarket

# %%
stonks=StonkMarket()

# %%
stonks.limbo()
# Out:
# notInTheMarket 10
# triggered feminist
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7F179933BE50>
# next

# %%
stonks.print_market()
# Out:
#                                                   name  num_posts  \
# 0                                          drake noyes       4055
# 1                                          two buttons       1804
# 2                               disappointed black guy       1541
# 3                                           undertaker       1436
# 4                                           fancy pooh       1407
# 5                                                 doge       1366
# 6                           buff doge vs crying cheems       1297
# 7                                     panik kalm panik       1186
# 8                                      expanding brain       1084
# 9                                 maybe i am a monster       1041
# 10                                          grumpy cat       1022
# 11                                      change my mind        930
# 12                          lisa simpsons presentation        900
# ...
