# %%
from src.stonks.market import StonkMarket

# %%
stonks=StonkMarket()

# %%
stonks.limbo()
# Out:
# notInTheMarket 66
# you wouldnt get it
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7F7C39539C70>
# next

# %%
stonks.print_market()
# Out:
#                                                   name  num_posts  \
# 0                                          drake noyes       2272
# 1                                          two buttons       1026
# 2                               disappointed black guy        834
# 3                                           undertaker        803
# 4                                           fancy pooh        752
# 5                                                 doge        723
# 6                                     panik kalm panik        649
# 7                           buff doge vs crying cheems        646
# 8                                      expanding brain        598
# 9                                 maybe i am a monster        531
# 10                                      change my mind        505
# 11                          lisa simpsons presentation        494
# 12                                        where banana        462
# ...

# %%
with APP.app_context():
    audit_is_template()
