# %%
from scripts.stonks import mh_reddit_stonks, mh_print_market

# %%
# %matplotlib inline
mh_reddit_stonks()
# Out:
# memes_done - 44242
# memes_found - 13204
# round - 10
# round time - 13 seconds,
# num left - 11720
# ETA - 1 day, 18 hours, 19 minutes, 20 seconds,
# bad images 6

# %%
mh_print_market()
# Out:
#                                                   name  num_posts  \
# 0                                 Blank White Template       2989
# 1                                     Black background        660
# 2                                Blank Comic Panel 2x2        472
# 3                             Blank Transparent Square        386
# 4                                Blank Comic Panel 1x2        246
# 5                                          Drake Blank        193
# 6                               Drake Hotline approves        162
# 7                               Tuxedo Winnie The Pooh        153
# 8                          Lisa Simpson's Presentation        151
# 9                                          Two Buttons        143
# 10                            They're The Same Picture        128
# 11                                    Panik Kalm Panik        122
# 12                              Disappointed Black Guy        122
# ...
