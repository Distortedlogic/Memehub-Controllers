# %%
from scripts.stonks import mh_reddit_stonks, mh_print_market, mh_audit_reddit_stonks

# %%
# %matplotlib inline
mh_audit_reddit_stonks()
# Out:
# num correct - 13657
# num wrong - 3503
# wolf of wallstreet
# True
# Meme/Template
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F56A7B216A0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7F56ADD9D250>
# hit enter for next image -- q to break -- k to kill

# %%
mh_reddit_stonks()

# %%
mh_print_market()
